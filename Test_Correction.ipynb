# %% [markdown]
# <a href="https://colab.research.google.com/github/isabelandreatta1/Unit_3/blob/main/Test_Correction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test Correction
#
# A raising start in the field of science has developed a computer program to simulate the human brain hoping to discover the origins of consciousness. This model includes neurons and their connections called synapses.
#
# To represent the brain in Fig 1, the scientist created three arrays called NEURON, CUR_OUTPUT and NUM_INPUTS. The array NEURON stores a number id for each neuron, whereas the second array contains the current output of each neuron in microvolts. The last array contains the number of inputs of each neuron. INPUT connections are identified by the balls (●) ending in the synapses.
#
#
# The number accompanying the synapses in a connection from neuron A to neuron B, indicates how strong the influence of the source neuron A is on the target B (0<strength<1.0) and if they work together (positive strength) or in opposite directions (negative strength). To store this information the strength of each input connection is included in a new array called STRENGTH and another array called SOURCE with the id of the source neuron.
#
# A function called check_inputs() returns True  if the total number of inputs for all the neurons is equal to the size of the array SOURCE and the array STRENGTH, otherwise it returns False. This helps test the integrity of the program.

# %% [markdown]
# # Questions:
#
# **(a) State the number of inputs for the NEURON[2]**
#
# 2 inputs
#
# **(b) State the strength and direction of all the input connections to NEURON[2]**
#
# Strenght: -0.2, 0.3
#
# Source: 2,1
#
# **(c) Create the algorithm for the function check_inputs()**

# %%
# creating a list of lists for the tables 

source = [4,1,3,1,2,1]
strength = [-0.5,0.5,-0.4,-0.2,0.3,0.2]
numinputs = [1,2,2,1]

# Create function check_inputs()
def check_inputs(): 
  if len(source) == len(strength) == sum(numinputs): 
    return True
  else : 
    return False 

check_inputs()
# Out:
# True

# %% [markdown]
# **(d) Another function get_index(id)returns the index of the array NEURON where the neuron with the id provided is stored. Assume that neuron ids are random integer numbers. Create a flow diagram for this function.**
#
# **(e) The function simulate() shown above, calculates the outputs of the neurons based on the arrays defined previously.  State one line in the code where a precondition is used.**
#
# if check_input()

# %% [markdown]
# function simulate(NEURON, CUR_OUTPUT, NUM_INPUTS, STRENGTH, SOURCE)
#
# if check_input()
# 	start_idx = 0
# loop n from 0 to len(NEURON) - 1
# 	end_idx = start_idx + NUM_INPUTS[n]
# 	out = 0.0
# 	loop k from start_idx to end_idx - 1
# temp = get_index(SOURCE[k])
# 		out += STRENGTH[temp] * CUR_OUTPUT[temp]
# end loop
# CUR_OUTPUT[n] = out
# start_idx = end_idx
# output “Output of neuron id”, NEURON[n], “ is ”, out
# end loop
# return CUR_OUTPUT
# else
# return “Error in the initialization”
# end if
#
# end function

# %% [markdown]
# (f) Trace the program simulate() with the arrays given above and show the output of NEURON[3].
# ![IMG_1006.jpg](data:image/jpeg;base64,...)
